# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = pd.read_csv(r"C:\Users\previ\Downloads\HDFC loan dataset (2)\HDFC loan dataset\Loan payments data.csv")

# %%
dataset.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male
# 4  9/23/2016 21:36            NaN   28               college  female

# %%
dataset.tail()
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# 495  10/11/2016  10/14/2016 19:08            3.0   28  High School or Below
# 496   9/26/2016  10/10/2016 20:02           14.0   26  High School or Below
# 497   9/26/2016   9/29/2016 11:49            3.0   30               college
# 498  11/10/2016  11/11/2016 22:40            1.0   38               college
# 499  10/11/2016  10/19/2016 11:58            8.0   28  High School or Below
#
#      Gender
# 495    male
# 496    male
# 497    male
# 498  female
# 499    male

# %%
dataset.isnull()
# Out:
#      Loan_ID  loan_status  Principal  terms  effective_date  due_date  \
# 0      False        False      False  False           False     False
# 1      False        False      False  False           False     False
# 2      False        False      False  False           False     False
# 3      False        False      False  False           False     False
# 4      False        False      False  False           False     False
# ..       ...          ...        ...    ...             ...       ...
# 495    False        False      False  False           False     False
# 496    False        False      False  False           False     False
# 497    False        False      False  False           False     False
# 498    False        False      False  False           False     False
# 499    False        False      False  False           False     False
#
#      paid_off_time  past_due_days    age  education  Gender
# 0            False           True  False      False   False
# ...

# %%
dataset.notnull()
# Out:
#      Loan_ID  loan_status  Principal  terms  effective_date  due_date  \
# 0       True         True       True   True            True      True
# 1       True         True       True   True            True      True
# 2       True         True       True   True            True      True
# 3       True         True       True   True            True      True
# 4       True         True       True   True            True      True
# ..       ...          ...        ...    ...             ...       ...
# 495     True         True       True   True            True      True
# 496     True         True       True   True            True      True
# 497     True         True       True   True            True      True
# 498     True         True       True   True            True      True
# 499     True         True       True   True            True      True
#
#      paid_off_time  past_due_days   age  education  Gender
# 0             True          False  True       True    True
# ...

# %%
dataset.shape
# Out:
# (500, 11)

# %%
dataset.shape[0]
# Out:
# 500

# %%
dataset.shape[1]
# Out:
# 11

# %%
dataset.isnull()
# Out:
#      Loan_ID  loan_status  Principal  terms  effective_date  due_date  \
# 0      False        False      False  False           False     False
# 1      False        False      False  False           False     False
# 2      False        False      False  False           False     False
# 3      False        False      False  False           False     False
# 4      False        False      False  False           False     False
# ..       ...          ...        ...    ...             ...       ...
# 495    False        False      False  False           False     False
# 496    False        False      False  False           False     False
# 497    False        False      False  False           False     False
# 498    False        False      False  False           False     False
# 499    False        False      False  False           False     False
#
#      paid_off_time  past_due_days    age  education  Gender
# 0            False           True  False      False   False
# ...

# %%
dataset.notnull()
# Out:
#      Loan_ID  loan_status  Principal  terms  effective_date  due_date  \
# 0       True         True       True   True            True      True
# 1       True         True       True   True            True      True
# 2       True         True       True   True            True      True
# 3       True         True       True   True            True      True
# 4       True         True       True   True            True      True
# ..       ...          ...        ...    ...             ...       ...
# 495     True         True       True   True            True      True
# 496     True         True       True   True            True      True
# 497     True         True       True   True            True      True
# 498     True         True       True   True            True      True
# 499     True         True       True   True            True      True
#
#      paid_off_time  past_due_days   age  education  Gender
# 0             True          False  True       True    True
# ...

# %%
dataset.isnull,sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 dataset.isnull,sum()
#
# TypeError: sum() takes at least 1 positional argument (0 given)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(400)

# %%
dataset.isnull().sum()/dataset.shape[0]*100
# Out:
# Loan_ID            0.0
# loan_status        0.0
# Principal          0.0
# terms              0.0
# effective_date     0.0
# due_date           0.0
# paid_off_time     20.0
# past_due_days     60.0
# age                0.0
# education          0.0
# Gender             0.0
# dtype: float64

# %%
(database.isnull().sum().sum()/dataset.shape[0]*dataset.shape[1])*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 (database.isnull().sum().sum()/dataset.shape[0]*dataset.shape[1])*100
#
# NameError: name 'database' is not defined

# %%
(database.isnull().sum().sum()/dataset.shape[0]*dataset.shape[1]))*100
# Out:
#   Cell In[22], line 1
#     (database.isnull().sum().sum()/dataset.shape[0]*dataset.shape[1]))*100
#                                                                      ^
# SyntaxError: unmatched ')'

# %%
(dataset.isnull().sum().sum()/dataset.shape[0]*dataset.shape[1])*100
# Out:
# np.float64(880.0000000000001)

# %%
import seaborn as sins

# %%
import matplotlib.pyplot as plt

# %%
sins.heatmap(dataset.isnull())
# Out:
# <Axes: >

# %%
#plt.show()
